# %% [markdown]
# # Ctrl Enter to install the package

# %%
# install openai
# !pip install openai

# install scrapy
# !pip install Scrapy

# install selenium
# !pip install selenium

# import pandas
import pandas as pd

# %%
import requests
from scrapy.http import HtmlResponse
from scrapy import Spider
from selenium import webdriver
from scrapy.selector import Selector
from selenium.webdriver.chrome.options import Options
from scrapy.http import HtmlResponse
import openai
openai.api_key = "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"

# %%
## Input file name

filename = "advanced-meta-content(vans sg plp).csv" ## Please input the filename for audit
output_filename = "Vans SG - PLP - 20230324" ## The filename of the outout file

## Set up the basic requirement
language = "English" ## Traditional Chinese // English
title_min_chars = 55 ## Character limit for title (min)
title_max_chars = 70 ## Character limit for title (max)
des_min_chars = 140 ## Character limit for Meta Description (min)
des_max_chars = 156 ## Character limit for Meta Description (max)


## adjust the prompt 
title_prompt = f"Rewrite the {title} to make it SEO friendly and natural in {language}. Focus on {query_list} but do not over do keywords. Make sure the page title match the SEO friendly standard and make sure the output of the answer contain the title ONLY. Please make sure the length of the output keep under {title_max_chars} character and more than {title_min_chars} characters. No need to include (80 character limit) or SEO within your answer"
description_promot = f"Rewrite {meta} to make the meta desciption SEO friendly in {language}. Do not stuff keyword and make it natural. Please make sure the length of the output keep under {des_max_chars} character and more than {des_min_chars} characters."

# %% [markdown]
# # Read CSV

# %%
df = pd.read_csv(filename)
df
# Out:
#                                             Landing Page  Page Type  \
# 0                       https://www.vans.com.sg/men.html        NaN
# 1                       https://www.vans.com.sg/men.html        NaN
# 2                     https://www.vans.com.sg/women.html        NaN
# 3                     https://www.vans.com.sg/women.html        NaN
# 4            https://www.vans.com.sg/season-sale-sg.html        NaN
# ...                                                  ...        ...
# 15975           https://www.vans.com.sg/all-slip-on.html        NaN
# 15976    https://www.vans.com.sg/men/clothing/pants.html        NaN
# 15977  https://www.vans.com.sg/women/shoes/navy-6-9-1...        NaN
# 15978                 https://www.vans.com.sg/women.html        NaN
# 15979  https://www.vans.com.sg/oldskool-breana-geerin...        NaN
#
#                        Query  Impressions  % Δ  Clicks  % Δ.1  Avg. Position  \
# ...

# %%
# group by "Landing Page" and "Query", and sum the "Clicks" column
grouped = df.groupby(['Landing Page', 'Query'], as_index=False)['Clicks'].sum()

# select the top 10 "Query" for each group based on the most clicks
grouped_top_10 = grouped.groupby('Landing Page').apply(lambda x: x.nlargest(3, 'Clicks')).reset_index(drop=True)

# create a new dataframe with columns "Landing Page" and "Query_list"
new_new_df = pd.DataFrame(columns=['Landing Page', 'Query_list'])

# fill in the values for the new dataframe
for lp in grouped_top_10['Landing Page'].unique():
    top_10_queries = grouped_top_10[grouped_top_10['Landing Page'] == lp]['Query'].tolist()
    new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)

# display the new dataframe
print(new_new_df)
# Out:
# C:\Users\Alan\AppData\Local\Temp\ipykernel_13216\397962231.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_13216\397962231.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_13216\397962231.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# ...

# %%
new_new_df
# Out:
#                                           Landing Page  \
# 0               https://www.vans.com.sg/66-supply.html
# 1                 https://www.vans.com.sg/acer-ni.html
# 2           https://www.vans.com.sg/all-authentic.html
# 3        https://www.vans.com.sg/all-checkerboard.html
# 4           https://www.vans.com.sg/all-comfycush.html
# ..                                                 ...
# 630  https://www.vans.com.sg/women/unisex-blue-navy...
# 631            https://www.vans.com.sg/womens-diy.html
# 632       https://www.vans.com.sg/woven-stackform.html
# 633          https://www.vans.com.sg/year-of-the-tiger
# 634  https://www.vans.com.sg/yearoftiger-collection...
#
#                                             Query_list
# 0           [vans 66 supply, vans outlet in singapore]
# 1                        [vans acer, acer ni, acer sg]
# 2    [vans authentic, vans authentic white, van aut...
# 3            [check vans, checker board, checkerboard]
# ...

# %% [markdown]
# Select the number of URLs

# %%
## select top 50 url 
new_new_df = new_new_df[0:10]
new_new_df
# Out:
#                                         Landing Page  \
# 0             https://www.vans.com.sg/66-supply.html
# 1               https://www.vans.com.sg/acer-ni.html
# 2         https://www.vans.com.sg/all-authentic.html
# 3      https://www.vans.com.sg/all-checkerboard.html
# 4         https://www.vans.com.sg/all-comfycush.html
# 5               https://www.vans.com.sg/all-era.html
# 6  https://www.vans.com.sg/all-era/black-mediumgr...
# 7            https://www.vans.com.sg/all-hoodie.html
# 8         https://www.vans.com.sg/all-old-skool.html
# 9   https://www.vans.com.sg/all-old-skool/1-8-3.html
#
#                                           Query_list
# 0         [vans 66 supply, vans outlet in singapore]
# 1                      [vans acer, acer ni, acer sg]
# 2  [vans authentic, vans authentic white, van aut...
# 3          [check vans, checker board, checkerboard]
# 4  [vans comfycush, vans comfycush old skool, van...
# 5              [vans era, vans era leather, van era]
# ...

# %% [markdown]
# # Generate Meta Content based on keyword list

# %%
import csv

# create empty lists for titles and meta descriptions
results = []

for index, row in new_new_df.iterrows():
    url = row['Landing Page']
    query_list = row['Query_list']
    options = Options()
    options.headless = True  # Run the browser in headless mode
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    scrapy_response = HtmlResponse(url=url, body=driver.page_source, encoding='utf-8')


    scrapy_response = HtmlResponse(url=url, body=scrapy_response.text, encoding='utf-8')


    # Get description
    ori_description = scrapy_response.xpath("//meta[@name='description']/@content")
    if ori_description:
        ori_description = ori_description.extract_first().encode('utf-8').decode('utf-8')
    else:
        ori_description = ""

    # Get title
    ori_title = scrapy_response.xpath("//title/text()")
    if ori_title:
        ori_title = ori_title[0].extract().encode('utf-8').decode('utf-8')
    else:
        ori_title = ""

    # Get h1
    ori_h1 = scrapy_response.xpath("//h1/text()")
    if ori_h1:
        h1_tag = []
        for i in scrapy_response.xpath("//h1/text()"):
            h1_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_h1 = [s.strip() for s in h1_tag if s.strip()]
    else:
        ori_h1 = ""    

    # Get h2
    ori_h2 = scrapy_response.xpath("//h2/text()")
    if ori_h2:
        h2_tag = []
        for i in scrapy_response.xpath("//h2/text()"):
            h2_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_h2 = [s.strip() for s in h2_tag if s.strip()]
    else:
        ori_h2 = ""     

    # Get h3
    ori_h3 = scrapy_response.xpath("//h3/text()")
    if ori_h3:
        h3_tag = []
        for i in scrapy_response.xpath("//h3/text()"):
            h3_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_h3 = [s.strip() for s in h3_tag if s.strip()]
    else:
        ori_h3 = "" 

    # # Get li
    ori_li = scrapy_response.xpath("//ul/text()")
    if ori_li:
        li_tag = []
        for i in scrapy_response.xpath("//li/text()"):
            li_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_li = [s.strip() for s in li_tag if s.strip()]
    else:
        ori_li = ""  

    ori_table = []

    for table in scrapy_response.xpath('//table'):
        headers = [h.xpath('string()').get().strip() for h in table.xpath('.//th')]
        rows = []
        for row in table.xpath('.//tr'):
            cells = [c.xpath('string()').get().strip() for c in row.xpath('.//td')]
            rows.append(cells)
        ori_table.append({
            'headers': headers,
            'rows': rows
        })

    if not ori_table:
        ori_table = None


    # Get content
    ori_content = scrapy_response.xpath("//p/text()")
    if ori_content:
        p_tag = []
        for i in scrapy_response.xpath("//p/text()"):
            p_tag.append(i.extract().encode('utf-8').decode('utf-8'))
            ori_content = [s.strip() for s in p_tag if s.strip()]
    else:
        ori_content = ""

    # Get spcific html
    ori_text = scrapy_response.xpath("//a[@class='product-item-link']/text()").getall()
    if ori_text:
        other_tag = []
        for i in scrapy_response.xpath("//a[@class='product-item-link']/text()").getall():
            other_tag.append(i.encode('utf-8').decode('utf-8'))
            ori_text = [s.strip() for s in ori_content if s.strip()]
    else:
        ori_text = ""

    while True:
    # create a chat completion request for the title
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "assistant"},
                {"role": "user", "content": f"Please rewrite {ori_title} for {url} based on {query_list} and return the result in {language}. Can reference {ori_text}. Please make sure the length of the output keep under {title_max_chars} character and more than {title_min_chars} characters"}
            ]
        )
        # extract the generated title from the response
        title = response['choices'][0]['message']['content']
        if len(title) < title_min_chars:
            print(f"Output length is too short ({len(title)} characters): {title}")
            # You can add code here to handle the case where the output is too short
        elif len(final_title) > title_max_chars:
            print(f"Output length is too long ({len(title)} characters): {title}")
            # You can add code here to handle the case where the output is too long
        else:
            break  
        title_response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "assistant"},
                {"role": "user", "content": f"Rewrite the {title} to make it SEO friendly and natural in {language}. Focus on {query_list} but do not over do keywords. Make sure the page title match the SEO friendly standard and make sure the output of the answer contain the title ONLY. Please make sure the length of the output keep under {title_max_chars} character and more than {title_min_chars} characters. No need to include (80 character limit) or SEO within your answer"}
            ]
        )
        
        final_title = title_response['choices'][0]['message']['content']
        if len(final_title) < title_min_chars:
            print(f"Output length is too short ({len(final_title)} characters): {final_title}")
            # You can add code here to handle the case where the output is too short
        elif len(final_title) > title_max_chars:
            print(f"Output length is too long ({len(final_title)} characters): {final_title}")
            # You can add code here to handle the case where the output is too long
        else:
            break        
        print(final_title)
    
    while True:
    # create a chat completion request for the meta description
        second_response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "assistant"},
                {"role": "user", "content": f"Please rewrite {ori_description} for {url} based on {query_list} in {language}. Can reference {ori_text}. Make sure the output of your answer contain meta description only in {language} and over write keywords. Please make sure the length of the output keep under {des_max_chars} character and more than {des_min_chars} characters."}
            ]
        )
        # extract the generated meta description from the response
        meta = second_response['choices'][0]['message']['content']
        meta_response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "assistant"},
                {"role": "user", "content": f"Rewrite {meta} to make the meta desciption SEO friendly in {language}. Do not stuff keyword and make it natural. Please make sure the length of the output keep under {des_max_chars} character and more than {des_min_chars} characters."}
            ]
        )
        final_meta = meta_response['choices'][0]['message']['content']
        if len(final_meta) < des_min_chars:
            print(f"Output length is too short ({len(final_meta)} characters): {final_meta}")
            # You can add code here to handle the case where the output is too short
        elif len(final_title) > des_max_chars:
            print(f"Output length is too long ({len(final_meta)} characters): {final_meta}")
            # You can add code here to handle the case where the output is too long
        else:
            break 
        print(final_meta)

    results.append({
        'Landing Page': url,
        'Query_list': query_list,
        "Old Title": ori_title,
        'Title': final_title,
        "Old Meta Desciption": ori_description,
        'Meta Description': final_meta
    })

with open(output_filename+'.csv', 'w', newline='',encoding='utf-16') as csvfile:
    fieldnames = ['Landing Page', 'Query_list', "Old Title",'Title', "Old Meta Desciption",'Meta Description']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for row in results:
        writer.writerow(row)
# Out:
# C:\Users\Alan\AppData\Local\Temp\ipykernel_13216\2228665010.py:10: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True  # Run the browser in headless mode
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13216\2228665010.py in <module>
#     180         'Title': final_title,
#     181         "Old Meta Desciption": ori_description,
# --> 182         'Meta Description': final_meta
#     183     })
#     184
#
# NameError: name 'final_meta' is not defined

# %%
import csv

# create empty lists for titles and meta descriptions
results = []

for index, row in new_new_df.iterrows():
    url = row['Landing Page']
    query_list = row['Query_list']
    options = Options()
    options.headless = True  # Run the browser in headless mode
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    scrapy_response = HtmlResponse(url=url, body=driver.page_source, encoding='utf-8')


    scrapy_response = HtmlResponse(url=url, body=scrapy_response.text, encoding='utf-8')


    # Get description
    ori_description = scrapy_response.xpath("//meta[@name='description']/@content")
    if ori_description:
        ori_description = ori_description.extract_first().encode('utf-8').decode('utf-8')
    else:
        ori_description = ""

    # Get title
    ori_title = scrapy_response.xpath("//title/text()")
    if ori_title:
        ori_title = ori_title[0].extract().encode('utf-8').decode('utf-8')
    else:
        ori_title = ""

    # Get h1
    ori_h1 = scrapy_response.xpath("//h1/text()")
    if ori_h1:
        h1_tag = []
        for i in scrapy_response.xpath("//h1/text()"):
            h1_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_h1 = [s.strip() for s in h1_tag if s.strip()]
    else:
        ori_h1 = ""    

    # Get h2
    ori_h2 = scrapy_response.xpath("//h2/text()")
    if ori_h2:
        h2_tag = []
        for i in scrapy_response.xpath("//h2/text()"):
            h2_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_h2 = [s.strip() for s in h2_tag if s.strip()]
    else:
        ori_h2 = ""     

    # Get h3
    ori_h3 = scrapy_response.xpath("//h3/text()")
    if ori_h3:
        h3_tag = []
        for i in scrapy_response.xpath("//h3/text()"):
            h3_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_h3 = [s.strip() for s in h3_tag if s.strip()]
    else:
        ori_h3 = "" 

    # # Get li
    ori_li = scrapy_response.xpath("//ul/text()")
    if ori_li:
        li_tag = []
        for i in scrapy_response.xpath("//li/text()"):
            li_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_li = [s.strip() for s in li_tag if s.strip()]
    else:
        ori_li = ""  

    ori_table = []

    for table in scrapy_response.xpath('//table'):
        headers = [h.xpath('string()').get().strip() for h in table.xpath('.//th')]
        rows = []
        for row in table.xpath('.//tr'):
            cells = [c.xpath('string()').get().strip() for c in row.xpath('.//td')]
            rows.append(cells)
        ori_table.append({
            'headers': headers,
            'rows': rows
        })

    if not ori_table:
        ori_table = None


    # Get content
    ori_content = scrapy_response.xpath("//p/text()")
    if ori_content:
        p_tag = []
        for i in scrapy_response.xpath("//p/text()"):
            p_tag.append(i.extract().encode('utf-8').decode('utf-8'))
            ori_content = [s.strip() for s in p_tag if s.strip()]
    else:
        ori_content = ""

    # Get spcific html
    ori_text = scrapy_response.xpath("//a[@class='product-item-link']/text()").getall()
    if ori_text:
        other_tag = []
        for i in scrapy_response.xpath("//a[@class='product-item-link']/text()").getall():
            other_tag.append(i.encode('utf-8').decode('utf-8'))
            ori_text = [s.strip() for s in ori_content if s.strip()]
    else:
        ori_text = ""

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "assistant"},
            {"role": "user", "content": f"You are a SEO expert. Please a SEO friendly title by rewriting {ori_title} for {url} based on {query_list} and the content: {ori_text} return the result in {language}. Please incide a call to action message like shop or buy make sure the length of the output keep under {title_max_chars} character and more than {title_min_chars} characters"}
        ]
    )
    # extract the generated title from the response
    title = response['choices'][0]['message']['content']
    while True:
        if len(title) < title_min_chars:
            print(f"Output length is too short ({len(title)} characters): {title}")
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "assistant"},
                    {"role": "user", "content": f"Please lengthen this title to {title_min_chars} characters:{title}"}
                ]
            )
            lengthen_title = response['choices'][0]['message']['content']
            print("Lengthen title: "+lengthen_title +" "+str(len(lengthen_title)))
            # Update the title with the shortened title
            title = lengthen_title
        elif len(title) > title_max_chars:
            print(f"Output length is too long ({len(title)} characters): {title}")
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "assistant"},
                    {"role": "user", "content": f"Please shorten this title to {title_max_chars} characters:{title}"}
                ]
            )
            shortened_title = response['choices'][0]['message']['content']
            print("Shorten title: "+shortened_title +" "+str(len(shortened_title)))
            # Update the title with the shortened title
            title = shortened_title
        else:
            break
     
    # create a chat completion request for the meta description
    second_response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "assistant"},
            {"role": "user", "content": f"Please rewrite {ori_description} for {url} based on {query_list} in {language}. Can reference {ori_text}. Make sure the output of your answer contain meta description only in {language} and over write keywords. Please make sure the length of the output keep under {des_max_chars} character and more than {des_min_chars} characters."}
        ]
    )
    # extract the generated meta description from the response
    meta = second_response['choices'][0]['message']['content']
    meta_response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "assistant"},
            {"role": "user", "content": f"You are s SEO expert. Please rewrite {meta} to make the meta desciption SEO friendly in {language}. Do not stuff keyword and make it natural. Please make sure the length of the output keep under {des_max_chars} character and more than {des_min_chars} characters."}
        ]
    )
    final_meta = meta_response['choices'][0]['message']['content']
    while True:
        if len(final_meta) < des_min_chars:
            print(f"Output length is too short ({len(final_meta)} characters): {final_meta}")
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "assistant"},
                    {"role": "user", "content": f"Please lengthen this title to {des_min_chars} characters:{final_meta}"}
                ]
            )
            final_meta = response['choices'][0]['message']['content']
            print("Lengthen des: "+final_meta +" "+str(len(final_meta)))
        elif len(final_meta) > des_max_chars:
            print(f"Output length is too long ({len(final_meta)} characters): {final_meta}")
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "assistant"},
                    {"role": "user", "content": f"Please shorten this title to {des_max_chars} characters:{final_meta}"}
                ]
            )
            final_meta = response['choices'][0]['message']['content']
            print("Shorten des: "+final_meta +" "+str(len(final_meta)))
        else:
            break 
    print(url)
    print(title)
    print(final_meta)
    results.append({
        'Landing Page': url,
        'Query_list': query_list,
        "Old Title": ori_title,
        'Title': title,
        "Old Meta Desciption": ori_description,
        'Meta Description': final_meta
    })

with open(output_filename+'.csv', 'w', newline='',encoding='utf-16') as csvfile:
    fieldnames = ['Landing Page', 'Query_list', "Old Title",'Title', "Old Meta Desciption",'Meta Description']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for row in results:
        writer.writerow(row)
# Out:
# C:\Users\Alan\AppData\Local\Temp\ipykernel_13216\2274525458.py:10: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True  # Run the browser in headless mode
# Output length is too long (85 characters): "Shop Vans 66 Supply at Singapore's Outlet - Find Unique Items on Vans Official Site"
# Shorten title: "Singapore Outlet: Shop Unique Vans 66 Supply on Official Site" 63
# Output length is too long (231 characters): Shop the latest Shoes, Clothing & Accessories at Vans.com.sg. Discover Men's, Women's, Kids & Infants styles in Singapore. Enjoy free delivery on orders over SGD100. Explore our 66 Supply collection today and find your perfect fit.
# Shorten des: Shop the latest Shoes, Clothing & Accessories at Vans.com.sg. Discover Men's, Women's, Kids & Infants styles. Free delivery on orders over SGD100. Explore our 66 Supply collection today! 186
# ...

# %%
pd.DataFrame(results)
# Out:
#                                         Landing Page  \
# 0             https://www.vans.com.sg/66-supply.html
# 1               https://www.vans.com.sg/acer-ni.html
# 2         https://www.vans.com.sg/all-authentic.html
# 3      https://www.vans.com.sg/all-checkerboard.html
# 4         https://www.vans.com.sg/all-comfycush.html
# 5               https://www.vans.com.sg/all-era.html
# 6  https://www.vans.com.sg/all-era/black-mediumgr...
# 7            https://www.vans.com.sg/all-hoodie.html
# 8         https://www.vans.com.sg/all-old-skool.html
# 9   https://www.vans.com.sg/all-old-skool/1-8-3.html
#
#                                           Query_list  \
# 0         [vans 66 supply, vans outlet in singapore]
# 1                      [vans acer, acer ni, acer sg]
# 2  [vans authentic, vans authentic white, van aut...
# 3          [check vans, checker board, checkerboard]
# 4  [vans comfycush, vans comfycush old skool, van...
# 5              [vans era, vans era leather, van era]
# ...

# %% [markdown]
# # Test

# %%
import csv

# create empty lists for titles and meta descriptions
results = []

for index, row in new_new_df.iterrows():
    url = row['Landing Page']
    query_list = row['Query_list']
    options = Options()
    options.headless = True  # Run the browser in headless mode
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    scrapy_response = HtmlResponse(url=url, body=driver.page_source, encoding='utf-8')


    scrapy_response = HtmlResponse(url=url, body=scrapy_response.text, encoding='utf-8')


    # Get description
    ori_description = scrapy_response.xpath("//meta[@name='description']/@content")
    if ori_description:
        ori_description = ori_description.extract_first().encode('utf-8').decode('utf-8')
    else:
        ori_description = ""

    # Get title
    ori_title = scrapy_response.xpath("//title/text()")
    if ori_title:
        ori_title = ori_title[0].extract().encode('utf-8').decode('utf-8')
    else:
        ori_title = ""

    # Get h1
    ori_h1 = scrapy_response.xpath("//h1/text()")
    if ori_h1:
        h1_tag = []
        for i in scrapy_response.xpath("//h1/text()"):
            h1_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_h1 = [s.strip() for s in h1_tag if s.strip()]
    else:
        ori_h1 = ""    

    # Get h2
    ori_h2 = scrapy_response.xpath("//h2/text()")
    if ori_h2:
        h2_tag = []
        for i in scrapy_response.xpath("//h2/text()"):
            h2_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_h2 = [s.strip() for s in h2_tag if s.strip()]
    else:
        ori_h2 = ""     

    # Get h3
    ori_h3 = scrapy_response.xpath("//h3/text()")
    if ori_h3:
        h3_tag = []
        for i in scrapy_response.xpath("//h3/text()"):
            h3_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_h3 = [s.strip() for s in h3_tag if s.strip()]
    else:
        ori_h3 = "" 

    # # Get li
    ori_li = scrapy_response.xpath("//ul/text()")
    if ori_li:
        li_tag = []
        for i in scrapy_response.xpath("//li/text()"):
            li_tag.append(i.extract().encode('utf-8').decode('utf-8'))
        ori_li = [s.strip() for s in li_tag if s.strip()]
    else:
        ori_li = ""  

    ori_table = []

    for table in scrapy_response.xpath('//table'):
        headers = [h.xpath('string()').get().strip() for h in table.xpath('.//th')]
        rows = []
        for row in table.xpath('.//tr'):
            cells = [c.xpath('string()').get().strip() for c in row.xpath('.//td')]
            rows.append(cells)
        ori_table.append({
            'headers': headers,
            'rows': rows
        })

    if not ori_table:
        ori_table = None


    # Get content
    ori_content = scrapy_response.xpath("//p/text()")
    if ori_content:
        p_tag = []
        for i in scrapy_response.xpath("//p/text()"):
            p_tag.append(i.extract().encode('utf-8').decode('utf-8'))
            ori_content = [s.strip() for s in p_tag if s.strip()]
    else:
        ori_content = ""

    # Get spcific html
    ori_text = scrapy_response.xpath("//a[@class='product-item-link']/text()").getall()
    if ori_text:
        other_tag = []
        for i in scrapy_response.xpath("//a[@class='product-item-link']/text()").getall():
            other_tag.append(i.encode('utf-8').decode('utf-8'))
            ori_text = [s.strip() for s in ori_content if s.strip()]
    else:
        ori_text = ""

  
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "assistant"},
            {"role": "user", "content": f"You are a SEO expert. Please a SEO friendly title by rewriting {ori_title} for {url} based on {query_list} and the content: {ori_text} return the result in {language}. Please make sure the length of the output keep under {title_max_chars} character and more than {title_min_chars} characters"}
        ]
    )
    # extract the generated title from the response
    title = response['choices'][0]['message']['content']
    while True:
        if len(title) < title_min_chars:
            print(f"Output length is too short ({len(title)} characters): {title}")
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "assistant"},
                    {"role": "user", "content": f"Please lengthen this title to {title_min_chars} characters:{title}"}
                ]
            )
            lengthen_title = response['choices'][0]['message']['content']
            print("Lengthen title: "+lengthen_title +" "+str(len(lengthen_title)))
            # Update the title with the shortened title
            title = lengthen_title
        elif len(title) > title_max_chars:
            print(f"Output length is too long ({len(title)} characters): {title}")
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "assistant"},
                    {"role": "user", "content": f"Please shorten this title to {title_max_chars} characters:{title}"}
                ]
            )
            shortened_title = response['choices'][0]['message']['content']
            print("Shorten title: "+shortened_title +" "+str(len(shortened_title)))
            # Update the title with the shortened title
            title = shortened_title
        else:
            break  

           
            
    print(url)
    print(title)
    results.append({
        'Landing Page': url,
        'Query_list': query_list,
        "Old Title": ori_title,
        'Title': title
    })
# Out:
# C:\Users\Alan\AppData\Local\Temp\ipykernel_13216\1370632558.py:10: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True  # Run the browser in headless mode
# https://www.vans.com.sg/66-supply.html
# "Vans 66 Supply: The Ultimate Outlet in Singapore for Latest Items"
# Output length is too long (74 characters): "Acer SG - Shop Vans Acer NI Collection in Singapore | Vans Official Site"
# Shorten title: "Acer SG - Vans NI Collection | Official Site" 46
# Output length is too short (46 characters): "Acer SG - Vans NI Collection | Official Site"
# Lengthen title: "Acer SG - Shop the Vans NI Collection on our Official Site" 60
# https://www.vans.com.sg/acer-ni.html
# "Acer SG - Shop the Vans NI Collection on our Official Site"
# Output length is too long (89 characters): "Shop the Best Selection of Vans Authentic Shoes in White - Official Vans Singapore Site"
# ...

# %%
pd.DataFrame(results)
# Out:
#                                         Landing Page  \
# 0             https://www.vans.com.sg/66-supply.html
# 1               https://www.vans.com.sg/acer-ni.html
# 2         https://www.vans.com.sg/all-authentic.html
# 3      https://www.vans.com.sg/all-checkerboard.html
# 4         https://www.vans.com.sg/all-comfycush.html
# 5               https://www.vans.com.sg/all-era.html
# 6  https://www.vans.com.sg/all-era/black-mediumgr...
# 7            https://www.vans.com.sg/all-hoodie.html
# 8         https://www.vans.com.sg/all-old-skool.html
# 9   https://www.vans.com.sg/all-old-skool/1-8-3.html
#
#                                           Query_list  \
# 0         [vans 66 supply, vans outlet in singapore]
# 1                      [vans acer, acer ni, acer sg]
# 2  [vans authentic, vans authentic white, van aut...
# 3          [check vans, checker board, checkerboard]
# 4  [vans comfycush, vans comfycush old skool, van...
# 5              [vans era, vans era leather, van era]
# ...

# %% [markdown]
# # No Keyword List

# %%
import csv

# create empty lists for titles and meta descriptions
results = []

for index, row in new_new_df.iterrows():
    url = row['Landing Page']
    query_list = row['Query_list']
    scrapy_response = requests.get(url)

    # Convert the response to an HtmlResponse object
    scrapy_response = HtmlResponse(url=url, body=scrapy_response.text, encoding='utf-8')

   
    # Get description
    ori_description = scrapy_response.xpath("//meta[@name='description']/@content")
    if ori_description:
        ori_description = ori_description.extract_first().encode('iso-8859-1').decode('utf-8')
    else:
        ori_description = ""

    # Get title
    ori_title = scrapy_response.xpath("//title/text()")
    if ori_title:
        ori_title = ori_title[0].extract().encode('iso-8859-1').decode('utf-8')
    else:
        ori_title = ""

    # Get content
    ori_content = scrapy_response.xpath("//p/text()")
    if ori_content:
        p_tag = []
        for i in scrapy_response.xpath("//p/text()"):
            p_tag.append(i.extract().encode('iso-8859-1').decode('utf-8'))
        ori_content = p_tag[20:100]
    else:
        ori_content = ""
    print(ori_content)

    while True:
    # create a chat completion request for the title
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "assistant"},
                {"role": "user", "content": f"Please rewrite {ori_title} for {url} based on {ori_content} and return the result in traditional Chinese. No need to include | AIG 香港. Please make sure the length of the output keep under {title_max_chars} character and more than {title_min_chars} characters"}
            ]
        )
        # extract the generated title from the response
        title = response['choices'][0]['message']['content']
        if len(title) < title_min_chars:
            print(f"Output length is too short ({len(title)} characters): {title}")
            # You can add code here to handle the case where the output is too short
        elif len(final_title) > title_max_chars:
            print(f"Output length is too long ({len(title)} characters): {title}")
            # You can add code here to handle the case where the output is too long
        else:
            break  
        title_response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "assistant"},
                {"role": "user", "content": f"Rewrite the {title} to make it SEO friendly and natural in traditional Chinese. No need to include | AIG 香港 and make sure the page title match the SEO friendly standard and make sure the output of the answer contain the title ONLY. Please make sure the length of the output keep under {title_max_chars} character and more than {title_min_chars} characters. No need to include (80 character limit) or SEO within your answer"}
            ]
        )
        final_title = title_response['choices'][0]['message']['content']
        if len(final_title) < title_min_chars:
            print(f"Output length is too short ({len(final_title)} characters): {final_title}")
            # You can add code here to handle the case where the output is too short
        elif len(final_title) > title_max_chars:
            print(f"Output length is too long ({len(final_title)} characters): {final_title}")
            # You can add code here to handle the case where the output is too long
        else:
            break        
        print(final_title)
    
    # create a chat completion request for the meta description
        second_response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "assistant"},
                {"role": "user", "content": f"Please rewrite {ori_description} for {url} by summarizing {ori_content} in traditional Chinese. Can reference {ori_content}. Make sure the output of your answer contain meta description only in traditional Chinese and over write keywords. Please make sure the length of the output keep under {des_max_chars} character and more than {des_min_chars} characters."}
            ]
        )
        # extract the generated meta description from the response
        meta = second_response['choices'][0]['message']['content']
        meta_response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "assistant"},
                {"role": "user", "content": f"Rewrite {meta} to make the meta desciption SEO friendly in traditional Chinese. Do not stuff keyword and make it natural. Please make sure the length of the output keep under {des_max_chars} character and more than {des_min_chars} characters."}
            ]
        )
        final_meta = meta_response['choices'][0]['message']['content']
        if len(final_meta) < des_min_chars:
            print(f"Output length is too short ({len(final_meta)} characters): {final_meta}")
            # You can add code here to handle the case where the output is too short
        elif len(final_title) > des_max_chars:
            print(f"Output length is too long ({len(final_meta)} characters): {final_meta}")
            # You can add code here to handle the case where the output is too long
        else:
            break 
        print(final_meta)

    results.append({
        'Landing Page': url,
        'Query_list': query_list,
        "Old Title": ori_title,
        'Title': final_title,
        "Old Meta Desciption": ori_description,
        'Meta Description': final_meta
    })

with open(output_filename+'-no keywords.csv', 'w', newline='',encoding='utf-16') as csvfile:
    fieldnames = ['Landing Page', 'Query_list', "Old Title",'Title', "Old Meta Desciption",'Meta Description']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for row in results:
        writer.writerow(row)
# Out:
# Output length is too short (4 characters): 禁止访问
# Output length is too short (7 characters): 無法進入此頁面
# 無法進入此頁面
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13216\1558324599.py in <module>
#      76
#      77     # create a chat completion request for the meta description
# ---> 78         second_response = openai.ChatCompletion.create(
#      79             model="gpt-3.5-turbo",
#      80             messages=[
#
# ~\anaconda3\lib\site-packages\openai\api_resources\chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ...

# %% [markdown]
# # Checking Code

# %%
url = "https://www.aig.com.hk/zh/personal/auto"
scrapy_response = requests.get(url)

    # Convert the response to an HtmlResponse object
scrapy_response = HtmlResponse(url=url, body=scrapy_response.text, encoding='utf-8')
scrapy_response
# Out:
# <200 https://www.aig.com.hk/zh/personal/auto>

# %%
scrapy_response.xpath("//p/text()")[0].extract().encode('iso-8859-1').decode('utf-8')
# Out:
# '\n                            JavaScript has been disabled on this browser.\n                            For a seamless experience, please enable the option to run JavaScript on this device\n                        '

# %%
scrapy_response.xpath("//p/text()")
# Out:
# [<Selector xpath='//p/text()' data='\n                            JavaScri...'>,
#  <Selector xpath='//p/text()' data='*ä¼°å\x83¹é\x9c\x80å°\x8fæ\x96¼ç\xad\x89æ\x96¼$1300000.'>,
#  <Selector xpath='//p/text()' data='å\x8f¸æ©\x9få¹´é½¡é\x9c\x80è¦\x81å\x9c¨18æ\xad²ä»¥ä¸\x8aå\x8f\x8a65...'>,
#  <Selector xpath='//p/text()' data='å\x8f¸æ©\x9få¹´é½¡é\x9c\x80è¦\x81å\x9c¨18æ\xad²ä»¥ä¸\x8aå\x8f\x8a65...'>,
#  <Selector xpath='//p/text()' data='*è«\x8bå¡«å¯«å¿\x85å¡«é\xa0\x85.'>,
#  <Selector xpath='//p/text()' data='*å\x84ªæ\x83\xa0æ¢\x9dæ¬¾å\x8f\x8aç´°å\x89\x87'>,
#  <Selector xpath='//p/text()' data='\n'>,
#  <Selector xpath='//p/text()' data='ç\x94±å\x8d³æ\x97¥èµ·è\x87³2023å¹´4æ\x9c\x8830æ\x97¥ï¼\x8cç¶²...'>,
#  <Selector xpath='//p/text()' data='å\x8f¦å¤\x96ï¼\x8cæ·¨ä¿\x9dè²»é\x81\x94HK$6,000æ\x88\x96ä»¥ä¸...'>,
#  <Selector xpath='//p/text()' data='Â\xa0'>,
#  <Selector xpath='//p/text()' data='*é\xa0\x88ç¶\x93'>,
# ...

# %%
p_tag = []
for i in scrapy_response.xpath("//p/text()"):
    p_tag.append(i.extract().encode('iso-8859-1').decode('utf-8'))

print(p_tag[:100])
p_tag_1 = p_tag[:150]
# Out:
# ['\n                            JavaScript has been disabled on this browser.\n                            For a seamless experience, please enable the option to run JavaScript on this device\n                        ', '請注意有關俄羅斯及烏克蘭的軍事衝突或會影響旅遊保險保障範圍及權益，以及美亞旅遊就往返受影響地區，或於地區內提供之旅遊相關支援服務。', '計劃去夢寐以求的國度放眼世界？或者去商務公幹、週末小旅行？', 'AIG旅遊智易保 (全年計劃) 為經常出門，一年多次到海外旅行或公幹的旅客提供最佳保障。全年計劃提供緊急醫療費用、人身意外保障、旅程取消、延誤保障等，即日來回中國大陸或澳門亦在保障範圍之內，令您隨時隨地放心出行。', 'AIG擁有自家24小時緊急支援團隊，當您身處海外，無論需要緊急支援或醫療建議，我們的團隊能即時透過熱線提供意見及或在危機中即時調配人員前往協助。', '*價格只供參考，保費將根據旅程地區、旅程長短及受保人數而計算，您可按此', '。', '#以上資料只供參考。有關詳盡條款，規定及不保事項概以', '為準。有關詳細的保障權益表和保費，請參閲', '或按', '。', '\xa0', '1a. 緊急醫療費用及援助 - 醫療費用', '\xa0', '\xa0', '\xa0', '1b. 緊急醫療費用及援助 - 緊急醫療運送', '\xa0', '\xa0', '\xa0', '1c. 緊急醫療費用及援助 - 運返費用', '\xa0', '\xa0', '\xa0', '1d. 緊急醫療費用及援助 - 海外住院現金津貼', '\xa0', '\xa0', '\xa0', '1e. 緊急醫療費用及援助 - 緊急啟程', '\xa0', '\xa0', '\xa0', '1f. 緊急醫療費用及援助 - 子女護送', '\xa0', '\xa0', '\xa0', '2a. 人身意外保障 - 乘搭交通工具之意外', '\xa0', '\xa0', '\xa0', '2b. 人身意外保障 - 其他意外', '\xa0', 
# ...

# %%
len(p_tag)
# Out:
# 100

# %%
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
          {"role": "system", "content": "assistant"},
          {"role": "user", "content": f"Please rewrite {p_tag_1}"}
         ]
    )
        # extract the generated title from the response
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
# ...
