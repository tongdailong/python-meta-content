# %%
# install openai
# !pip install openai

# install scrapy
# !pip install Scrapy

import pandas as pd
# Out:
# Requirement already satisfied: openai in c:\users\alan\anaconda3\lib\site-packages (0.27.2)
# Requirement already satisfied: aiohttp in c:\users\alan\anaconda3\lib\site-packages (from openai) (3.8.4)
# Requirement already satisfied: requests>=2.20 in c:\users\alan\anaconda3\lib\site-packages (from openai) (2.28.1)
# Requirement already satisfied: tqdm in c:\users\alan\anaconda3\lib\site-packages (from openai) (4.64.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alan\anaconda3\lib\site-packages (from requests>=2.20->openai) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alan\anaconda3\lib\site-packages (from requests>=2.20->openai) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\alan\anaconda3\lib\site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\alan\anaconda3\lib\site-packages (from requests>=2.20->openai) (1.26.11)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\alan\anaconda3\lib\site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\alan\anaconda3\lib\site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\alan\anaconda3\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\alan\anaconda3\lib\site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\alan\anaconda3\lib\site-packages (from aiohttp->openai) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\alan\anaconda3\lib\site-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied: colorama in c:\users\alan\anaconda3\lib\site-packages (from tqdm->openai) (0.4.5)
# Requirement already satisfied: Scrapy in c:\users\alan\anaconda3\lib\site-packages (2.6.2)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (1.5.0)
# Requirement already satisfied: lxml>=3.5.0 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (4.9.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (2.0.5)
# Requirement already satisfied: Twisted>=17.9.0 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (22.2.0)
# Requirement already satisfied: tldextract in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (3.2.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (1.21.0)
# Requirement already satisfied: zope.interface>=4.1.3 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (5.4.0)
# Requirement already satisfied: pyOpenSSL>=16.2.0 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (22.0.0)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (0.3.0)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (1.6.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (1.0.4)
# Requirement already satisfied: setuptools in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (63.4.1)
# Requirement already satisfied: cryptography>=2.0 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (37.0.1)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (1.1.0)
# Requirement already satisfied: service-identity>=16.0.0 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (18.1.0)
# Requirement already satisfied: protego>=0.1.15 in c:\users\alan\anaconda3\lib\site-packages (from Scrapy) (0.1.16)
# Requirement already satisfied: cffi>=1.12 in c:\users\alan\anaconda3\lib\site-packages (from cryptography>=2.0->Scrapy) (1.15.1)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\alan\anaconda3\lib\site-packages (from itemloaders>=1.0.1->Scrapy) (0.10.0)
# Requirement already satisfied: six>=1.6.0 in c:\users\alan\anaconda3\lib\site-packages (from parsel>=1.5.0->Scrapy) (1.16.0)
# Requirement already satisfied: attrs>=16.0.0 in c:\users\alan\anaconda3\lib\site-packages (from service-identity>=16.0.0->Scrapy) (21.4.0)
# Requirement already satisfied: pyasn1-modules in c:\users\alan\anaconda3\lib\site-packages (from service-identity>=16.0.0->Scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in c:\users\alan\anaconda3\lib\site-packages (from service-identity>=16.0.0->Scrapy) (0.4.8)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\alan\anaconda3\lib\site-packages (from Twisted>=17.9.0->Scrapy) (21.3.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\alan\anaconda3\lib\site-packages (from Twisted>=17.9.0->Scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\alan\anaconda3\lib\site-packages (from Twisted>=17.9.0->Scrapy) (4.3.0)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\alan\anaconda3\lib\site-packages (from Twisted>=17.9.0->Scrapy) (1.0.2)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\alan\anaconda3\lib\site-packages (from Twisted>=17.9.0->Scrapy) (20.2.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\alan\anaconda3\lib\site-packages (from Twisted>=17.9.0->Scrapy) (15.1.0)
# Requirement already satisfied: requests-file>=1.4 in c:\users\alan\anaconda3\lib\site-packages (from tldextract->Scrapy) (1.5.1)
# Requirement already satisfied: requests>=2.1.0 in c:\users\alan\anaconda3\lib\site-packages (from tldextract->Scrapy) (2.28.1)
# Requirement already satisfied: idna in c:\users\alan\anaconda3\lib\site-packages (from tldextract->Scrapy) (3.3)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\alan\anaconda3\lib\site-packages (from tldextract->Scrapy) (3.6.0)
# Requirement already satisfied: pycparser in c:\users\alan\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.0->Scrapy) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alan\anaconda3\lib\site-packages (from requests>=2.1.0->tldextract->Scrapy) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\alan\anaconda3\lib\site-packages (from requests>=2.1.0->tldextract->Scrapy) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\alan\anaconda3\lib\site-packages (from requests>=2.1.0->tldextract->Scrapy) (2.0.4)

# %%
import requests
from scrapy.http import HtmlResponse
import openai
openai.api_key = "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"

# %%
filename = "advanced-meta-content.csv"
output_filename = "G-niib meta content"

# %%
df = pd.read_csv(filename)
df
# Out:
#                                            Landing Page Page Type  \
# 0                               https://www.g-niib.com/  Homepage
# 1                               https://www.g-niib.com/  Homepage
# 2                               https://www.g-niib.com/  Homepage
# 3                               https://www.g-niib.com/  Homepage
# 4                               https://www.g-niib.com/  Homepage
# ...                                                 ...       ...
# 2070  https://www.g-niib.com/zh-hant/service-cover-l...    Others
# 2071  https://www.g-niib.com/zh-hant/service-cover-l...    Others
# 2072  https://www.g-niib.com/zh-hant/service-cover-l...    Others
# 2073  https://www.g-niib.com/zh-hant/service-cover-l...    Others
# 2074  https://www.g-niib.com/zh-hant/service-cover-l...    Others
#
#                    Query  Impressions       % Δ  Clicks     % Δ.1  \
# 0                  gniib         1325 -0.164565     110 -0.208633
# 1                 g-niib         1247 -0.025020      86 -0.075269
# 2                 g niib         1246 -0.090511      64 -0.304348
# 3             geniebiome          172  0.202797      38 -0.269231
# 4     geniebiome limited           71  0.044118      27 -0.129032
# ...                  ...          ...       ...     ...       ...
# 2070              天水圍 新界            3       NaN       0       NaN
# 2071           將軍澳家庭醫務中心            3       NaN       0       NaN
# 2072          進康醫務中心 將軍澳            2 -0.666667       0       NaN
# 2073                朗屏診所            4 -0.200000       0       NaN
# 2074               元朗大橋村            4  3.000000       0       NaN
#
#       Avg. Position         Δ   URL CTR     % Δ.2
# 0          2.544906 -0.159382  0.083019 -0.052749
# 1          2.608661  0.409286  0.068966 -0.051539
# 2          2.788122  0.559655  0.051364 -0.235118
# 3          1.563953  0.326191  0.220930 -0.392442
# 4          1.154930  0.066694  0.380282 -0.165834
# ...             ...       ...       ...       ...
# 2070       8.333333       NaN  0.000000       NaN
# 2071      23.333333       NaN  0.000000       NaN
# 2072      19.500000  0.333333  0.000000       NaN
# 2073      15.250000 -2.350000  0.000000       NaN
# 2074      38.000000 -2.000000  0.000000       NaN
#
# [2075 rows x 11 columns]

# %%
# group by "Landing Page" and "Query", and sum the "Clicks" column
grouped = df.groupby(['Landing Page', 'Query'], as_index=False)['Clicks'].sum()

# select the top 10 "Query" for each group based on the most clicks
grouped_top_10 = grouped.groupby('Landing Page').apply(lambda x: x.nlargest(10, 'Clicks')).reset_index(drop=True)

# create a new dataframe with columns "Landing Page" and "Query_list"
new_new_df = pd.DataFrame(columns=['Landing Page', 'Query_list'])

# fill in the values for the new dataframe
for lp in grouped_top_10['Landing Page'].unique():
    top_10_queries = grouped_top_10[grouped_top_10['Landing Page'] == lp]['Query'].tolist()
    new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)

# display the new dataframe
print(new_new_df)
# Out:
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
# C:\Users\Alan\AppData\Local\Temp\ipykernel_15752\1064423094.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_new_df = new_new_df.append({'Landing Page': lp, 'Query_list': top_10_queries}, ignore_index=True)
#                                           Landing Page  \
# 0                              https://www.g-niib.com/
# 1    https://www.g-niib.com/assets/frontend/common/...
# 2                       https://www.g-niib.com/zh-hans
# 3                 https://www.g-niib.com/zh-hans/about
# 4    https://www.g-niib.com/zh-hans/blog/detail/%E5...
# ..                                                 ...
# 117  https://www.g-niib.com/zh-hant/service-cover-l...
# 118  https://www.g-niib.com/zh-hant/service-cover-l...
# 119  https://www.g-niib.com/zh-hant/service-cover-l...
# 120  https://www.g-niib.com/zh-hant/service-cover-l...
# 121  https://www.g-niib.com/zh-hant/service-cover-l...
#
#                                             Query_list
# 0    [gniib, g-niib, g niib, geniebiome, geniebiome...
# 1    [813 醫療中心, 813醫療中心, good health medical practi...
# 2     [geniebiome limited, geniebiome, geniebiome ltd]
# 3                                         [geniebiome]
# 4    [咖啡刺激腸胃, 一日咖啡因, 促排便, 促进肠道蠕动, 咖啡 大便, 咖啡 排便, 咖啡 ...
# ..                                                 ...
# 117                 [黃大仙中心診所, 黃大仙家庭醫務中心, 黃大仙家庭醫務中心 評論]
# 118  [上水時代醫療, 上水盈健, 上水盈健醫務中心, 上水診所, 上水龍豐診所, 仁安體檢中心,...
# 119                                [天水圍 新界, 將軍澳家庭醫務中心]
# 120                                       [進康醫務中心 將軍澳]
# 121                                      [元朗大橋村, 朗屏診所]
#
# [122 rows x 2 columns]

# %%
import csv

# create empty lists for titles and meta descriptions
results = []

for index, row in new_new_df.iterrows():
    url = row['Landing Page']
    query_list = row['Query_list']
    scrapy_response = requests.get(url)

    # Convert the response to an HtmlResponse object
    scrapy_response = HtmlResponse(url=url, body=scrapy_response.text, encoding='utf-8')

   
    # Get description
    ori_description = scrapy_response.xpath("//meta[@name='description']/@content")
    if ori_description:
        ori_description = ori_description.extract_first()
    else:
        ori_description = ""

    # Get title
    ori_title = scrapy_response.xpath("//title/text()")
    if ori_title:
        ori_title = ori_title[0].extract()
    else:
        ori_title = ""

    # Get content
    ori_content = scrapy_response.xpath("//p/text()")
    if ori_content:
        ori_content = ori_content[0].extract()
    else:
        ori_content = ""


    # create a chat completion request for the title
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "assistant"},
            {"role": "user", "content": f"Please rewrite {ori_title} for {url} based on {query_list} and return in traditional Chinese. Can reference {ori_content} "}
        ]
    )
    # extract the generated title from the response
    title = response['choices'][0]['message']['content']
    title_response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "assistant"},
            {"role": "user", "content": f"Check if the {title} is in traditional Chinese. If not, please write it in traditional Chinese. Make it is a page title and match the SEO friendly standard and make sure the output of the answer contain the title ONLY. No need to include (80 character limit) or SEO within your answer"}
        ]
    )
    final_title = title_response['choices'][0]['message']['content']
    print(final_title)
    
    # create a chat completion request for the meta description
    second_response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "assistant"},
            {"role": "user", "content": f"Please rewrite {ori_description} for {url} based on {query_list} in traditional Chinese. Can reference {ori_content}. Make sure the output of your answer contain the meta description only and it is in traditional Chinese and keep the character limit to 80 Chinese chracter"}
        ]
    )
    # extract the generated meta description from the response
    meta = second_response['choices'][0]['message']['content']
    meta_response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "assistant"},
            {"role": "user", "content": f"Deoes {meta} look like a meta description and return in traditioanl Chinese? Make sure it is in traditional Chinese and keep the character limit to 80 Chinese chracter"}
        ]
    )
    final_meta = meta_response['choices'][0]['message']['content']
    print(final_meta)

    results.append({
        'Landing Page': url,
        'Query_list': query_list,
        "Old Title": ori_title,
        'Title': final_title,
        "Old Meta Desciption": ori_description,
        'Meta Description': final_meta,
    })

with open(output_filename, 'w', newline='') as csvfile:
    fieldnames = ['Landing Page', 'Query_list', "Old Title",'Title', "Old Meta Desciption",'Meta Description']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for row in results:
        writer.writerow(row)
# Out:
# 本主頁介紹GenieBiome Limited，以科研重建健康微生態為使命。我們的網址包括gniib、g-niib、g niib、geniebiome、geniebiome limited、geniebiome ltd、gnib、genie biome、niib和gini b等。腸道微生物菌群與人類細胞有密切的關係，當中微生物會幫助調節許多的生理過程，例如︰新陳代謝和免疫反應，而腸道微生物菌群失去平衡時，更可能導致各種健康問題。
# G-NiiB是香港中文大學創立的生物科技公司，提供專為亞洲人打造之產品，包括微生態診斷、風險評估、微生態平衡配方及自然活菌治療等。腸道微生物失衡會影響多項生理功能，G-NiiB產品為您量身打造。
# 機構名稱 - 813醫療中心、Good Health Medical Practices Limited、彌敦道26號12樓、愷頤家庭醫學中心、晉柏醫務中心、晉樂醫療、智賢中西醫療中心及沙田澤祥街9號
# 本文件列出GNIIB醫療保險計劃涵蓋的813醫療中心，包括good health medical practices limited、彌敦道26號12樓、愷頤家庭醫學中心、晉柏醫務中心、晉樂醫療、智賢中西醫療中心等機構名稱。另外，還包括沙田澤祥街9號。請見附表以獲得更詳細資訊。
# GenieBiome Limited | 用科研重建健康微生態
# G-NiiB是一家由香港中文大學衍生的生物科技公司，提供精準微生態診斷及風險測試、微生態平衡配方、天然活菌及治療等服務，專為亞洲人而設。肠道微生物菌群與人類細胞有密切關係，微生物可調節新陳代謝和免疫反應等生理過程。失衡可能導致多種問題。
# 關於 GenieBiome Limited | 用科研重建健康微生態
# G-NiiB® 是精進微生物科技有限公司及其子公司的註冊商標，其核心有2個“ I”。我們秉持創新和誠信為核心價值，不斷追求超越想象的科研創新，實現看似不可能的任務。G-NiiB的科研團隊正在構建全球最大的腸道微生物亞洲大數據，為下一代健康的未來提供基於科研證據的創新解決方案。
# 咖啡對腸道的影響：適量飲用促進腸道蠕動，但過量飲用可能引起腸胃問題。- 中醫師解析
# G-NiiB是香港中文大學衍生的生物科技公司，提供亞洲人專屬的精確微生態診斷及風險測試、平衡配方、新一代天然微生物和治療等服務。許多人喝咖啡以提神，但咖啡因對身體的影響只持續5小時，並可能導致疲勞。
# 不少人慣用咖啡提神、增加專注力，因咖啡含咖啡因（Caffeine）成分，是中樞神經的興奮劑。咖啡因促進多巴胺神經傳導物質分泌，也可抑制腺苷（Adenosine）神經傳導物質，防止腺苷誘發想睡的功能，有醒神效果。然而，咖啡因的影響時間約5小時，當濃度逐漸下降時，也會使人感到疲勞。咖啡還有助於腸胃蠕動，但攝取量適中較佳，過量反而可能影響健康。可以選擇去咖啡因（Decaf）咖啡享受咖啡之約。
# G-NiiB是香港中文大學的生物科技公司，提供亞洲人專供的微生態診斷、風險評估、平衡配方和治療。但過量飲用咖啡因的咖啡將對身體造成負面影響，如影響腸胃蠕動和感到疲勞。咖啡因攝取上限需注意，以維持健康生活。
# 喝酒後的腸道三大變化 - GenieBiome Limited | 用科研重建健康微生態
# G-NiiB是由香港中文大學衍生的生物科技公司，專為亞洲人設計，提供精準微生態診斷及風險測試、配方及治療，解決飲酒後肚痾、喝酒腹瀉等腸胃問題。飲酒容易影響腸道機能，增加腸道惡菌生長風險，G-NiiB的專業團隊能給予有效支持。
# 面對2023年冬季流感高峰期，建議加強免疫力、重建健康微生態。- Title: "面對2023年冬季流感高峰期，建議加強免疫力、重建健康微生態。"
# 2023冬季流感高峰期即將到來，保持健康尤為重要。G-NiiB提供精準微生態診斷及風險測試、平衡配方及新一代天然活菌，有效增強抵抗力，降低流感併發症風險。
# 地中海飲食對腸道好菌定殖有益嗎？ | GenieBiome
# 地中海飲食對腸道微生態影響深遠，飲食模式改變腸菌多樣性。G-NiiB專為亞洲人，提供精準微生態診斷及風險評估、平衡配方及活菌治療。定殖有益菌、降炎症，減代謝性疾病風險。
# 大腸癌檢測方法：入侵性檢查、基因血液測試及大便免疫化學測試 | 近年大腸癌患者數量上升趨勢
# G-NiiB是由香港中文大學衍生出的生物科技公司，專注於提供精確微生態診斷及風險測試、微生態平衡配方、新一代天然活菌及治療等服務，特別針對亞洲人而設。大腸癌是一種極為常見的癌症，早期症狀不明顯，但若能在小息肉階段早期發現並治療，存活率可高達100%。目前香港的大腸癌檢測方法包括大便隱血檢測、照腸鏡和M3CRC細菌基因檢測技術，可檢測出不同階段的大腸癌風險。
# 重新撰寫: 微生態益生菌的10項黃金準則：選擇Smart數量！- GenieBiome Limited | 以科研重建健康微生態
#
# 若你對微生態益生菌有熱愛，一定會想知道如何選擇及食用益生菌，增強微生物群體的功效。以下是10項黃金準則，指南你在日常饮食中更精明度益生菌使用：
#
# 1. 選擇多樣化的菌種
# 2. 確認菌株符合你的需求
# 3. 檢查有效成分
# 4. 選擇高效益菌產品
# 5. 確認穩定性
# 6. 多元化飲食
# 7. 保持平衡
# 8. 注意菌株的存活和滅活狀況
# 9. 考慮問題和費用
# 10. 尋找適合你配方的益生菌
#
# 想要成為專家，需要掌握數量和種類的概念。還需監控及跟踪益生菌攝入量，了解你的身體對含益生菌的飲食反應。此黃金準則指南你，選擇Smart數量微生態益生菌。
# 初生嬰兒肌膚嫩滑，人人羨慕。然而，有些嬰兒在3個月後的皮膚竟變得又紅又腫、痕癢無比，「濕敏」問題逐漸浮現，令父母大感不解：「我們都沒有皮膚問題，為什麼BB卻天生有濕敏？」濕敏是什麼，請參考以下內容。
# G-NiiB是香港中文大學旗下生物科技公司，專為亞洲人提供微生態診斷及風險測試、微生態平衡配方、天然活菌及治療等服務，可解決初生嬰兒「濕敏」問題、緩解皮膚紅腫痕癢等問題。
# 大腸腺瘤切除後2年再生-GenieBiome Limited | 以科研重建健康微生態
# G-NiiB是由香港中文大學孵化的生物科技公司，專為亞洲人提供精準微生態診斷及風險測試、微生態平衡配方、新一代活菌和治療服務。創辦人為知名臨床醫生科學家，專業團隊涵蓋微生物學、宏基因組學、生物信息學、疾病生物標誌物、食品技術、臨床試驗、知識產權開發和商業策略等多個學科。
# 在農曆新年美食誘惑當前，人們往往會食用高脂高糖的食物，不過這容易導致腹脹、便秘等消化不良的問題。若要維護腸胃健康，建議改用對腸胃有益、促進消化和營養吸收的烹飪方式。炒、煮、炸、蒸、燒、焗等6種常見烹調法，有些對腸胃健康有益，而有些則可能阻礙營養吸收、助長惡菌生長、破壞腸道微生態，因此需要注意。哪一種烹調方式對腸胃最好？- 介紹多種煮法，供參考。
# 使用把G-NiiB精準微生態診斷、風險測試和平衡配方納入日常飲食，有助於克服消化不良和腸胃不適問題，更健康的食物煮法也能促進營養吸收，維持腸道微生態平衡。趁農曆新年，轉換飲食習慣吧！(80字)
# 如何透過大便型態辨識腸道菌？ - GenieBiome Limited | 以科研重新構建健康微生態
# G-NiiB是香港中文大學的子公司，專注於亞洲人的微生物生態健康管理。糞便顏色、形態和硬度可反映腸道健康狀態，進食速度和消化情況也會影響糞便狀態。
# 根據囡囡網，港媽Carmen與囡囡早前確診COVID-19，加上囡囡須接種疫苗，擔心其年紀輕未能表達不適。Carmen 發現G-NiiB 免疫+（SIM01配方）可改善腸道微生態，減輕接種疫苗後副作用。至今服用SIM01配方後，囡囡精神狀態改善、腸道狀況健康，甚至過敏情況有改善。Carmen相信服用SIM01配方可減低接種疫苗後不良反應甚至副作用。因此，作為家長的她高度推薦SIM01配方。
# G-NiiB是一家香港中文大學的生物科技公司，專注於為亞洲人提供精確的微生態診斷和風險評估，以及配方、新一代自然活菌和治療，以實現微生物平衡。Carmen媽媽曾服用G-NiiB的SIM01配方，並發現她和她的孩子的腸道健康獲得改善，並減輕了接種疫苗後的不良反應。她強烈推薦這種配方。
# 金融老闆Shane的腸道問題：微生態失衡易導致肚瀉｜G-NiiB「微生態配方」免疫＋的功效
# G-NiiB是由香港中文大學衍生的生物科技公司，專注於亞洲人微生態保健，提供精準診斷及風險測試、平衡配方及治療，改善腸道失衡引致的肚瀉等問題。
# G-NiiB免疫+成為亞太區最優秀益生菌之一，榮獲NutraIngredients-Asia 2022最佳益生菌獎 | Pro Gut益生菌值得推薦
# 由中大科研單位研發的 G-NiiB，提供精準腸道微生態評估及治療方案，以及新一代天然活菌產品，針對亞洲人的需求。G-NiiB配方 SIM01 可協助恢復腸道微生態平衡，提升免疫力，有效減輕兒童及青少年接種疫苗後的副作用。
# 用科研重建健康微生態的GenieBiome Limited最新研究指出，SIM01配方有效抵抗細菌和病毒感染，特別對於長者和長期病患者，因腸道微生態失衡而免疫力較弱，影響其免疫力及感染病毒的風險。而中文大學醫學院最新雙盲研究更證實，SIM01腸道微生態免疫力配方不但可減低接種疫苗後不良反應，更能大幅減少其他細菌和病毒感染的風險，同時改善睡眠、情緒和皮膚質素！
# G-NiiB是香港中文大學的生物科技公司，專門解決腸道微生態失衡所引起的免疫風險和細菌病毒感染等問題。SIM01腸道微生態免疫力配方經最新研究證實有效降低疫苗不良反應，同時降低細菌和病毒感染風險，並改善睡眠、情緒、皮膚質素等問題。
# 用科研重建健康微生態 - GenieBiome Limited 的「收集糞便樣本指南」
# 本網頁提供 G-NiiB CRCcore 大腸癌風險檢測收集糞便樣本指南影片，教學如何收集糞便樣本，包括糞便收集、糞便樣本收集、糞便樣本收集點和糞便樣本瓶收集等步驟。點擊進入網頁，開始學習如何收集糞便樣本。
# 作為保險從業員的Martin，每日生活十分繁忙，有很多會議和需要外出見客，導致每一天用餐時間不能定時，加上覺得自己年輕，沒有服用營養補充品的習慣。早前確診後，出現多個後遺症，不時頭暈，更需要服用頭暈丸止暈，嚴重影響日常生活與工作表現。但是在服用GenieBiome Limited的SIM01後，後遺症不再出現，Martin回復康復之前的水平！
# G-NiiB是從香港中文大學發展而來的生物科技公司，提供精確微生態診斷、風險測試、微生態平衡配方及治療服務。保險從業員Martin因為生活繁忙並未服用營養補充品，導致頭暈等後遺症，影響了他的日常工作。不過G-NiiB的治療方法有效地解決了他的問題。
# GenieBiome Limited：重建健康微生態，緩解壓力情緒與提升健康狀況 | g_niib紅色、藍色分別的全部療效来源
# 壓力情緒與腸道健康緊密相關，G-NiiB專注研究腸道微生物對不同疾病的影響，提供產品改善腸腦軸反應。腸腦聯繫影響情緒和睡眠。
# 根據g_niib紅色和藍色顯示，腸道頑疾是一個嚴重的問題 - GenieBiome限公司提供健康微生態方案
# G-NiiB在微生物研究領域領先，團隊研究腸道微生物對疾病的影響，提供診斷和治療產品。大腸癌患者可透過大便隱血測試、照腸鏡或M3CRC細菌基因檢測技術進行風險驗出。大便可了解微生物的重要性。
# 重建腸道微生態：腸脑轴和情绪的关系
# DSE文憑試即將開考，了解腸腦軸可影響情緒。G-NiiB團隊以微生物研究為領域，研究腸道微生物對健康的重要性，提供治療產品。治療omicron症狀和痰火核位置問題，掌握腸道微生物對心理壓力的影響，助力健康生活。
# 在GenieBiome Limited中，用科研重建健康微生態，以紅色和藍色的G niib分別為標誌，關注腸道黏膜和黏膜的重要性。黏膜層是腸道醫學中的一個關鍵因素，也稱為黏液層，通常涉及到黏液細胞的產生和分泌。國際醫學研究指出，腸道菌群失衡與常見的3大過敏反應有密切關係。通過平衡腸道微生態，能夠預防或有助於緩解濕敏等過敏症狀。
# 中大科研│GenieBiome Limited：利用科研重建健康微生態 | g-niib.com
# G-NiiB是一家香港中文大學衍生的生物科技公司，提供精準微生態診斷及風險測試、平衡配方和新一代活菌等產品，專為亞洲人設計。團隊包括微生物學、宏基因組學、生物信息學、疾病生物標誌物、食品技術、臨床試驗和知識產權開發等專家。產品包括中大科研、geniebiome、geniebiome ltd、gnib covid、gniib新冠和中大微生態免疫力配方等。
# 四成健康的香港1000名人士是否存在腸道菌群失衡？免疫配方的其他益處。
# G-NiiB是香港中文大學的創新產品，由跨學科專家團隊提供支援。其提供精準的微生態診斷與風險評估，以及針對亞洲人的微生態平衡配方。根據調查，在近千名健康人中，將近40％的人存在腸道菌群失衡問題。此配方不僅適用於新型病毒患者，而是針對所有人的免疫配方。
# 據護佳技術微膠囊研發的「微生態免疫力配方」臨床數據顯示，該配方有效促進新型病毒患者康復，不論是痊癒速度、發炎指數、產生中和新型病毒抗體以及腸道微生態狀況等免疫指數均明顯提升，有助提升市民免疫力。
# G-NiiB是從香港中文大學孵化出的生物科技公司，提供精準微生態診斷及風險測試、微生態平衡配方、天然活菌及治療，專為亞洲人而設。臨床數據顯示，該公司的「微生態免疫力配方」能夠加速痊癒、降低發炎指數、提高中和病毒抗體及改善腸道微生態狀況。護佳微膠囊技術亦被採用。
# 中大港大聯合研究：青春雙歧桿菌可提高疫苗成效
# 研究發現，未達抗體水平的超過半數接種科興或復必泰疫苗的人士缺乏青春雙歧桿菌，該益生菌是由香港中文大學研發，針對亞洲人而設。
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15752\1876424204.py in <module>
#      45     # extract the generated title from the response
#      46     title = response['choices'][0]['message']['content']
# ---> 47     title_response = openai.ChatCompletion.create(
#      48         model="gpt-3.5-turbo",
#      49         messages=[
#
# ~\anaconda3\lib\site-packages\openai\api_resources\chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~\anaconda3\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# ~\anaconda3\lib\site-packages\openai\api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     224             request_timeout=request_timeout,
#     225         )
# --> 226         resp, got_stream = self._interpret_response(result, stream)
#     227         return resp, got_stream, self.api_key
#     228
#
# ~\anaconda3\lib\site-packages\openai\api_requestor.py in _interpret_response(self, result, stream)
#     617         else:
#     618             return (
# --> 619                 self._interpret_response_line(
#     620                     result.content.decode("utf-8"),
#     621                     result.status_code,
#
# ~\anaconda3\lib\site-packages\openai\api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     680         stream_error = stream and "error" in resp.data
#     681         if stream_error or not 200 <= rcode < 300:
# --> 682             raise self.handle_error_response(
#     683                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     684             )
#
# RateLimitError: The server had an error while processing your request. Sorry about that!

# %%
import csv
import unicodedata

with open(output_filename+'.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Landing Page', 'Query_list', 'Old Title', 'Title', 'Old Meta Desciption', 'Meta Description']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for row in results:
        normalized_row = {}
        for key, value in row.items():
            normalized_value = unicodedata.normalize('NFKD', str(value))
            normalized_row[key] = normalized_value.encode('ascii', 'ignore').decode('utf-8')
        writer.writerow(normalized_row)
